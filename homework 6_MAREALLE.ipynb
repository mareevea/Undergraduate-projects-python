# %%
# 1
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
y1 = np.array ([0,11,21.6,32,35.1,37.2,39.2,40.4,42.4,43.2,45.2,49.2,55.1,64.1,70.4,77.8,90,100])
y=y1/100
x1 = np.array([0,1,2,4,6,10,20,30,40,43.2,50,60,70,80,85,90,96,100])
x = x1/100

fig = plt .figure ()
plt.plot ( x, y ,label = 'data')
x_graph = np.linspace(np.min(x), np.max(x), 50)

plt.xlabel ('xb moles of propanol in liquid')
plt.ylabel ('yb moles of propanol in vapor')
plt.title ('yb vs xb  ')
plt.show()

# %%
temp = np.array ([100.0,
95.0,
92.0,
90.5,
89.3,
88.5,
88.1,
87.9,
87.8,
87.8,
87.9,
88.3,
89.0,
90.5,
91.5,
92.8,
95.0,
97.3
])

fig = plt .figure ()
plt.plot ( x, temp , label = 'LIQUID')
x_graph = np.linspace(np.min(x), np.max(x), 50)

plt.xlabel ('xb and yb of propanol')
plt.ylabel ('temp')
plt.title ('temp vs x and y')


plt.plot(y, temp, label = 'VAPOR')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# c) The mole fraction of n-propanol when the liquid phase is 0. 3 is 0.4.
#
# Therefore the mass fraction:
#     Assume 100 moles
#
#     40 moles of n-propanol = mass/(60.09)
#
#     mass of propanol = 2403.36
#
#     60 moles of water = mass/(18 g/mol)
#
#     mass of water = 1080g
#
#     MASS FRACTION
#     = 2403.36/(1080+2403.36)
#     = 0.689

# %%
# 2 #y = (1- (1/0.5))*xb +(0.3/0.5)

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
y1 = np.array ([0,11,21.6,32,35.1,37.2,39.2,40.4,42.4,43.2,45.2,49.2,55.1,64.1,70.4,77.8,90,100])
y=y1/100
x1 = np.array([0,1,2,4,6,10,20,30,40,43.2,50,60,70,80,85,90,96,100])
x = x1/100

y2 = np.array ([0.6,0])
x2 = np.array([0,0.6])



x_graph = np.linspace(np.min(x), np.max(x), 50)



fig = plt.figure(figsize= (10,7))
plt.plot ( x, y ,label = 'yb and xb data')
plt.plot(x2,y2,label = 'straight line',color = 'red')
plt.xlabel('xb')
plt.ylabel('yb')
plt.legend(loc = 'best')
plt.title('yb vs xb')
plt.grid(axis = 'both')

plt.show()

# %% [markdown]
# The concentration of propanol in the vapor stream is 0.4 moles
# The concentration of propanol in the liquid stream is 0.2 moles

# %%
# Fraction of n-propanol recovered as the purified product
Ans = (0.4/0.3)*0.5
print ('The fraction of n-propanol in the feed stream is recovred as purified product:', Ans)
# Out:
# The fraction of n-propanol in the feed stream is recovred as purified product: 0.6666666666666667
