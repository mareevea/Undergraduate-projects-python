# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('exam_grades.csv')
dataset
# Out:
#     exam  student_id  grade
# 0      1           1   86.0
# 1      1           2   65.0
# 2      1           3   70.0
# 3      1           4   98.0
# 4      1           5   89.0
# 5      1           6    NaN
# 6      1           7   75.0
# 7      1           8   56.0
# 8      1           9   90.0
# 9      1          10   81.0
# 10     2           1   79.0
# 11     2           2   60.0
# 12     2           3   78.0
# 13     2           4   75.0
# 14     2           5    NaN
# 15     2           6   80.0
# 16     2           7   87.0
# 17     2           8   82.0
# 18     2           9   95.0
# 19     2          10   96.0
# 20     3           1   78.0
# 21     3           2   80.0
# 22     3           3   87.0
# 23     3           4    NaN
# 24     3           5   89.0
# 25     3           6   90.0
# 26     3           7  100.0
# 27     3           8   72.0
# 28     3           9   73.0
# 29     3          10   75.0
# 30     4           1    NaN
# 31     4           2   80.0
# ...

# %%
dataset_new = dataset.fillna(0)
dataset_new
# Out:
#     exam  student_id  grade
# 0      1           1   86.0
# 1      1           2   65.0
# 2      1           3   70.0
# 3      1           4   98.0
# 4      1           5   89.0
# 5      1           6    0.0
# 6      1           7   75.0
# 7      1           8   56.0
# 8      1           9   90.0
# 9      1          10   81.0
# 10     2           1   79.0
# 11     2           2   60.0
# 12     2           3   78.0
# 13     2           4   75.0
# 14     2           5    0.0
# 15     2           6   80.0
# 16     2           7   87.0
# 17     2           8   82.0
# 18     2           9   95.0
# 19     2          10   96.0
# 20     3           1   78.0
# 21     3           2   80.0
# 22     3           3   87.0
# 23     3           4    0.0
# 24     3           5   89.0
# 25     3           6   90.0
# 26     3           7  100.0
# 27     3           8   72.0
# 28     3           9   73.0
# 29     3          10   75.0
# 30     4           1    0.0
# 31     4           2   80.0
# ...

# %%
dataset_new[dataset_new.grade >= 70]
# Out:
#     exam  student_id  grade
# 0      1           1   86.0
# 2      1           3   70.0
# 3      1           4   98.0
# 4      1           5   89.0
# 6      1           7   75.0
# 8      1           9   90.0
# 9      1          10   81.0
# 10     2           1   79.0
# 12     2           3   78.0
# 13     2           4   75.0
# 15     2           6   80.0
# 16     2           7   87.0
# 17     2           8   82.0
# 18     2           9   95.0
# 19     2          10   96.0
# 20     3           1   78.0
# 21     3           2   80.0
# 22     3           3   87.0
# 24     3           5   89.0
# 25     3           6   90.0
# 26     3           7  100.0
# 27     3           8   72.0
# 28     3           9   73.0
# 29     3          10   75.0
# 31     4           2   80.0
# 32     4           3   81.0
# 33     4           4   82.0
# 34     4           5   83.0
# 35     4           6   84.0
# 36     4           7   85.0
# 37     4           8   86.0
# 38     4           9   87.0
# ...

# %%
dataset2 = dataset_new['grade']>=70
dataset2.sum()
# Out:
# 42

# %%
#Mean grade 1
exam1 = dataset_new.query('exam == 1')
exam1
# Out:
#    exam  student_id  grade
# 0     1           1   86.0
# 1     1           2   65.0
# 2     1           3   70.0
# 3     1           4   98.0
# 4     1           5   89.0
# 5     1           6    0.0
# 6     1           7   75.0
# 7     1           8   56.0
# 8     1           9   90.0
# 9     1          10   81.0

# %%
exam1.mean()
# Out:
# exam           1.0
# student_id     5.5
# grade         71.0
# dtype: float64

# %%
exam2 = dataset_new.query('exam == 2')
exam2
exam2.mean()
# Out:
# exam           2.0
# student_id     5.5
# grade         73.2
# dtype: float64

# %%
exam3 = dataset_new.query('exam == 3')
exam3

exam3.mean()
# Out:
# exam           3.0
# student_id     5.5
# grade         74.4
# dtype: float64

# %%
exam4 = dataset_new.query('exam == 4')
exam4

exam4.mean()
# Out:
# exam           4.0
# student_id     5.5
# grade         75.6
# dtype: float64

# %%
exam5 = dataset_new.query('exam == 5')
exam5
exam5.mean()
# Out:
# exam           5.0
# student_id     5.5
# grade         84.6
# dtype: float64

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

dataset_new.grade
plt.hist(dataset_new.grade)
plt.title("Histogram")
plt.xlabel("Grades")
plt.ylabel("Frequency")
plt.show()
